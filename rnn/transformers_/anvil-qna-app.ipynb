# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

# %%
nlp = pipeline('question-answering', model = 'deepset/roberta-base-squad2', tokenizer = 'deepset/roberta-base-squad2')
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
wiki_text = """
Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.
Their long occupation, initially in varying forms of isolation as hunter-gatherers, has made the region
highly diverse, second only to Africa in human genetic diversity
"""

# %%
qna = {
    'question': 'When did humans arrived in India?',
    'context': wiki_text
}

# %%
nlp(qna)
# Out:
# {'score': 0.7152793407440186,
#  'start': 76,
#  'end': 92,
#  'answer': '55,000 years ago'}

# %%
# !pip install anvil-uplink
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ws4py: filename=ws4py-0.5.1-py3-none-any.whl size=45228 sha256=f87bd60d480617286763e115746df2e68734d67f3aee61dd73d5e6562e9b7336
#   Stored in directory: /root/.cache/pip/wheels/2e/7c/ad/d9c746276bf024d44296340869fcb169f1e5d80fb147351a57
# Successfully built ws4py
# ...

# %%
import anvil.server

# %%
anvil.server.connect("server_22PMERODJSRZFAZMEGL35FGW-46Y6Z5ZNHOFGN3YD")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default Environment" as SERVER

# %%
@anvil.server.callable
def answer_questions(question_text, context_text):
    qna = {
        'question': question_text,
        'context': context_text
    }
    res = nlp(qna)['answer']
    return res
